# %%
pip install pandas matplotlib openpyxl
# Out:
# Requirement already satisfied: pandas in c:\users\teena\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: matplotlib in c:\users\teena\anaconda3\lib\site-packages (3.7.1)
# Requirement already satisfied: openpyxl in c:\users\teena\anaconda3\lib\site-packages (3.0.10)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\teena\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\teena\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\teena\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\teena\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\teena\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\teena\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\teena\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\teena\anaconda3\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\teena\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\teena\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: et_xmlfile in c:\users\teena\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\teena\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('ECOMM DATA.xlsx')

# %%
print(data.head())
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# 0   TEC-AC-10003033  Technology  Accessories
# 1   FUR-CH-10003950   Furniture       Chairs
# 2   TEC-PH-10004664  Technology       Phones
# 3   TEC-PH-10004583  Technology       Phones
# 4  TEC-SHA-10000501  Technology      Copiers
#
#                                         Product Name     Sales Quantity  \
# 0  Plantronics CS510 - Over-the-Head monaural Wir...  2309.650        7
# 1          Novimex Executive Leather Armchair, Black  3709.395        9
# 2                  Nokia Smart Phone, with Caller ID  5175.171        9
# 3                     Motorola Smart Phone, Cordless  2892.510        5
# 4                     Sharp Wireless Fax, High-Speed  2832.960        8
#
#   Discount    Profit  Shipping Cost  Order Priority
# 0      0.0  762.1845         933.57        Critical
# 1      0.1 -288.7650         923.63        Critical
# 2      0.1  919.9710         915.49          Medium
# 3      0.1  -96.5400         910.16          Medium
# 4      0.0  311.5200         903.04        Critical
#
# [5 rows x 24 columns]

# %%
total_sales = data['Sales'].sum()
print(f'Total Sales: ${total_sales:.2f}')
# Out:
# Total Sales: $12642501.91

# %%
data['Order Date'] = pd.to_datetime(data['Order Date'])
data.set_index('Order Date', inplace=True)
sales_trends = data['Sales'].resample('M').sum()

# %%
plt.figure(figsize=(12, 6))
sales_trends.plot()
# Out:
# <Axes: xlabel='Order Date'>

# %%
best_selling_products = data.groupby('Product Name')['Sales'].sum().sort_values(ascending=False)
print(best_selling_products.head(10))
# Out:
# Product Name
# Apple Smart Phone, Full Size                                86935.7786
# Cisco Smart Phone, Full Size                                76441.5306
# Motorola Smart Phone, Full Size                             73156.3030
# Nokia Smart Phone, Full Size                                71904.5555
# Canon imageCLASS 2200 Advanced Copier                       61599.8240
# Hon Executive Leather Armchair, Adjustable                  58193.4841
# Office Star Executive Leather Armchair, Adjustable          50661.6840
# Harbour Creations Executive Leather Armchair, Adjustable    50121.5160
# Samsung Smart Phone, Cordless                               48653.4600
# Nokia Smart Phone, with Caller ID                           47877.7857
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(12, 6))
best_selling_products.head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='Product Name'>

# %%
plt.figure(figsize=(12, 6))
sales_trends.plot()
plt.title('Sales Trends Over Time')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
best_selling_products.head(10).plot(kind='bar')
plt.title('Top 10 Best-Selling Products')
plt.xlabel('Product Name')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
